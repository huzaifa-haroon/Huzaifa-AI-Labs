# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6KlbVhEwQ_YUvN6hh6eXvzWMfZU5l0jxZgH29PINnNIEw")


MODEL = "models/gemini-3.6-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: Hello
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Error: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# You: Exit
# Goodbye

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6KlbVhEwQ_YUvN6hh6eXvzWMfZU5l0jxZgH29PINnNIEw")


MODEL = "gemini-3.5-flash"


def book_agent(user_input):

    prompt = f"""
Act as a simple rule-based AI agent called the "Personalized Book Recommendation Agent."

Your job is to recommend a book based on 5 inputs provided by the user:
1. Reader's Age
2. Favorite Genre
3. Current Mood
4. Recently Read Book
5. Candidate Book (the book to check)

Use simple IF-THEN rules to match the inputs:
- Check if the candidate book matches the Favorite Genre.
- Check if it fits the Current Mood.
- Check if it matches the Age group.
- Check if it connects to the Recently Read book.

Give one of these 4 outputs along with a short 1-sentence reason:
- Highly Recommended
- Recommended
- Maybe
- Not Recommended

Here are your rule examples to follow:
- If Genre and Mood both match -> Output: Highly Recommended
- If Genre matches and Mood fits -> Output: Recommended
- If Genre and Age group match -> Output: Recommended
- If Mood does not match the Genre -> Output: Maybe
- If Genre and Topic both match -> Output: Highly Recommended

User Request: {user_input}
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Book Recommendation Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = book_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Book Recommendation Agent Started (type 'exit' to stop)
#
#
# Agent:
#  Hello! I am the **Personalized Book Recommendation Agent**.
#
# I am ready to help you find your next great read! To get started, please provide me with the following 5 inputs:
#
# 1. **Reader's Age**
# 2. **Favorite Genre**
# 3. **Current Mood**
# 4. **Recently Read Book**
# 5. **Candidate Book** (the book you want me to check for you)
#
# Once you give me these details, I will apply my rules and let you know if the candidate book is Highly Recommended, Recommended, Maybe, or Not Recommended!
#
#
# Agent:
#  **Recommendation:** Recommended
#
# **Reason:** *A Farewell to Arms* matches your favorite genre (Classics) and is highly appropriate for your age group (23), serving as an excellent literary follow-up to *Crime and Punishment*.
#
# You: Exit
# Goodbye
