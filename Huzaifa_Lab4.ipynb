# %% [markdown]
# <a href="https://colab.research.google.com/github/huzaifa-haroon/Huzaifa-AI-Labs/blob/main/Huzaifa_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from google import genai
from google.colab import userdata

client = genai.Client(api_key=userdata.get("API_KEY"))


MODEL = "models/gemini-3.5-flash"

fuuast_teachers = {
    "Artificial Intelligence": "Miss Uzma",
    "Software Engineering": "Sir Kashif",
    "Operating System": "Dr. Khalid",
    "Compiler Construction": "Miss Naheed",
    "Natural Language Processing": "Dr. Sarim"
}


def travel_agent(user_input):

    prompt = f"""
You are an Informative Agent Expert in info about Federal Urdu University of Pakistan.

Answer the Student's Queries Clearly. If you can't find info about anything online or in our dictionaries then just say no.

use this dictionary to answer questions regarding subjects and teachers : {fuuast_teachers}

User request: {user_input}
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini University Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Gemini University Agent Started (type 'exit' to stop)
#
# You: Hello
#
# Agent:
#  Hello! I am your Informative Agent Expert for the Federal Urdu University of Pakistan (FUUAST).
#
# How can I help you today? Please feel free to ask any questions you have about the university, departments, subjects, or teachers!
#
# You: who is the current vice chancellor of University?
#
# Agent:
#  The current Vice Chancellor of the Federal Urdu University of Arts, Sciences & Technology (FUUAST) is **Prof. Dr. Zabta Khan Shinwari**.
#
# You: Who teaches Artificial Intelligence?
#
# Agent:
#  Based on the university records, **Miss Uzma** teaches Artificial Intelligence at the Federal Urdu University of Pakistan.
#
# You: What does Dr. Khalid teach?
# Error: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# You:  What does Dr. Khalid teach?
#
# Agent:
# ...
